# %%
import pandas as pd
import glob
from sklearn.ensemble import RandomForestClassifier

# %%
all_files = glob.glob('data/*.csv')
all_files
# Out:
# ['data/04-07_carbonhealth_and_braidhealth.csv',
#  'data/04-14_carbonhealth_and_braidhealth.csv',
#  'data/04-21_carbonhealth_and_braidhealth.csv',
#  'data/04-28_carbonhealth_and_braidhealth.csv',
#  'data/05-05_carbonhealth_and_braidhealth.csv',
#  'data/05-12_carbonhealth_and_braidhealth.csv',
#  'data/05-19_carbonhealth_and_braidhealth.csv',
#  'data/05-26_carbonhealth_and_braidhealth.csv',
#  'data/06-02_carbonhealth_and_braidhealth.csv',
#  'data/06-09_carbonhealth_and_braidhealth.csv',
#  'data/06-16_carbonhealth_and_braidhealth.csv',
#  'data/06-23_carbonhealth_and_braidhealth.csv',
#  'data/06-30_carbonhealth_and_braidhealth.csv',
#  'data/07-07_carbonhealth_and_braidhealth.csv',
#  'data/07-14_carbonhealth_and_braidhealth.csv',
#  'data/07-21_carbonhealth_and_braidhealth.csv',
#  'data/07-28_carbonhealth_and_braidhealth.csv',
#  'data/08-04_carbonhealth_and_braidhealth.csv',
#  'data/08-11_carbonhealth_and_braidhealth.csv',
#  'data/08-18_carbonhealth_and_braidhealth.csv',
# ...

# %%
df = pd.concat((pd.read_csv(f) for f in all_files))
#for each file in all_files, read csv and concatenate into data

# %%
df
# Out:
#       batch_date                     test_name       swab_type  \
# 0     2020-04-07          SARS COV 2 RNA RTPCR  Nasopharyngeal
# 1     2020-04-07               SARS-CoV-2, NAA   Oropharyngeal
# 2     2020-04-07          SARS CoV w/CoV 2 RNA   Oropharyngeal
# 3     2020-04-07          SARS COV 2 RNA RTPCR  Nasopharyngeal
# 4     2020-04-07          SARS CoV w/CoV 2 RNA  Nasopharyngeal
# ...          ...                           ...             ...
# 7289  2020-10-20  COVID-19 PCR External Result           Nasal
# 7290  2020-10-20               SARS-CoV-2, NAA           Nasal
# 7291  2020-10-20               SARS-CoV-2, NAA           Nasal
# 7292  2020-10-20       Rapid COVID-19 PCR Test           Nasal
# 7293  2020-10-20       Rapid COVID-19 PCR Test           Nasal
#
#      covid19_test_results  age high_risk_exposure_occupation  \
# 0                Negative   58                          True
# 1                Negative   35                         False
# ...
